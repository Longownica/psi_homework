# %% [markdown]
# # Ridge Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn import linear_model
import scipy.stats as stats
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import model_selection

# %% [markdown]
# Rozważmy następujący zbiór punktów:

# %%
true_fun = lambda X: np.cos(1.5 * np.pi * X)
n_samples=20
x = np.sort(np.random.rand(n_samples))
y = true_fun(x) + np.random.randn(n_samples) * 0.1
x=np.vstack(x)

# %% [markdown]
# # Przykład
# Proszę wykonać regresję (Ridge Regression) na powyższym zbiorze danych

# %%
clf = Ridge(alpha=1.0)
clf.fit(x, y) 

x_plot = np.vstack(np.linspace(0, 1, 20))
plt.plot(x_plot, clf.predict(x_plot), color='blue',linewidth=3)
plt.plot(x, y, 'ok');
plt.show()

# %% [markdown]
# ## Regresja liniowa

# %%
# prepare models
models = []
predicts = []
names=[]
models.append(('LR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression()) ))
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
x_plot = np.vstack(np.linspace(-3, 3, 1000))
plt.plot(x, y, 'ok');
for i in range(len(models)):
    #print(i)
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# LR degree 2
# LR degree 20

# %% [markdown]
# # Zadanie
# Proszę wykonać
# * regresję dla wielomianów o stopniu **20**
# * regresję (Ridge Regression) dla wielomianów o stopniu **20** oraz
#    * alpha = 1
#    * alpha = 10 000
#    * alpha = 0.0001

# %%
   # prepare models
models = []
predicts = []
names=[]
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
x_plot = np.vstack(np.linspace(-3, 3, 1000))
plt.plot(x, y, 'ok');
for i in range(len(models)):
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
# Out:
# LR degree 20

# %%
ridge_clfs=[]
ridge_names=[]
rigde_predicts=[]
ridge_clfs.append(('RR alpha=1', Ridge(alpha=1.0)))
ridge_clfs.append(('RR alpha=10000', Ridge(alpha=10000)))
ridge_clfs.append(('RR alpha=0.0001', Ridge(alpha=0.0001)))
    
    
x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, clf in ridge_clfs:
    print(name)
    clf.fit(x, y)
    rigde_predicts.append(clf.predict(x_plot))
    ridge_names.append(name)
    
x_plot = np.vstack(np.linspace(-3, 3, 1000))
plt.plot(x, y, 'ok');
for i in range(len(ridge_clfs)):
    plt.plot(x_plot, rigde_predicts[i],linewidth=3,label=ridge_names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
    
plt.legend()    
plt.show()
# Out:
# RR alpha=1
# RR alpha=10000
# RR alpha=0.0001

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr alpha za pomocą komendy **GridSearchCV**.

# %%
from sklearn.model_selection import GridSearchCV
seed=123
kfold = model_selection.KFold(n_splits=10, shuffle=True, random_state=seed)
grid = GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), linear_model.LinearRegression()),
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 6, 7]},
                    cv=kfold,
                    refit=False)
grid.fit(x, y)
print("Best pn degree: " + str(grid.best_params_['polynomialfeatures__degree']))


parameters = {'alpha':[0.000000001, 0.0001, 0.1, 1, 2, 3, 4, 10]}
ridge_model = Ridge()
grid2 = GridSearchCV(ridge_model, parameters, cv=5)
grid2.fit(x, y)
print("Best ridge degree: " + str(grid2.best_estimator_.alpha))
# Out:
# Best pn degree: 5
# Best ridge degree: 10

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr <tt>alpha</tt> za pomocą metody <tt>GridSearchCV</tt> dla danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.
#
# *  policz r_square score.

# %%
import pandas as pd
df_adv = pd.read_csv('https://raw.githubusercontent.com/przem85/bootcamp/master/statistics/Advertising.csv', index_col=0)
X = df_adv[['TV', 'radio','newspaper']]
y = df_adv['sales']
df_adv.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), linear_model.LinearRegression()),
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 6, 7, 25]},
                    cv=kfold,
                    refit=False)
grid.fit(X, y)
print("Best pn degree: " + str(grid.best_params_['polynomialfeatures__degree']))

parameters = {'alpha':[0.000000001, 0.0001, 0.1, 1, 2, 3, 4, 10, 100, 1000, 10000, 1000000]}
ridge_model = Ridge()
grid2 = GridSearchCV(ridge_model, parameters, cv=5)
grid2.fit(X, y)
print("Best ridge degree: " + str(grid2.best_estimator_.alpha))
# Out:
# Best pn degree: 3
# Best ridge degree: 1000

# %%
from sklearn import  metrics
model = make_pipeline(PolynomialFeatures(3), linear_model.LinearRegression())
model.fit(X, y)
print("R^2: {}".format(metrics.r2_score(y, model.predict(X))))
# Out:
# R^2: 0.9920754398977076
