# %%
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)

print(keras.__version__)
# Out:
# 2.8.2
# 2.8.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# Each pixel intensity is represented as a byte (0 to 255):

# %%
X_train_full.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# * Podzielmy pełny zestaw treningowy na zestaw walidacyjny i zestaw treningowy.
# * Kolor pikseli skalujemy również do zakresu 0-1 i przekształcamy na zmiennoprzecinkowe, dzieląc przez 255.

# %%
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.

# %%
plt.imshow(X_train[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
y_train
# Out:
# array([4, 0, 7, ..., 3, 0, 5], dtype=uint8)

# %% [markdown]
# Będziemy używać klas numerycznych i nazw.

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

class_names[y_train[0]]
# Out:
# 'Coat'

# %% [markdown]
# Możemy narysować więcej przykładów treningowych.

# %%
n_rows = 4
n_cols = 10
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]], fontsize=12)
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# # Zad
# Porównaj wyniki działań różnych optymalizacji
# *
# ```python
# sgd = keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
# ```
# *
# ```python
# Adam = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
# ```
# *
# ```python
# Adam = keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)
# ```
#
# https://keras.io/optimizers/

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)



model2 = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 300)               235500
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd = keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model2.compile(loss="sparse_categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history2 = model2.fit(X_train, y_train, epochs=30,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 1719/1719 [==============================] - 10s 5ms/step - loss: 0.5065 - accuracy: 0.8211 - val_loss: 0.3797 - val_accuracy: 0.8630
# Epoch 2/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3751 - accuracy: 0.8631 - val_loss: 0.3520 - val_accuracy: 0.8716
# Epoch 3/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3411 - accuracy: 0.8729 - val_loss: 0.3404 - val_accuracy: 0.8746
# Epoch 4/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3176 - accuracy: 0.8824 - val_loss: 0.3141 - val_accuracy: 0.8830
# Epoch 5/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3005 - accuracy: 0.8883 - val_loss: 0.3145 - val_accuracy: 0.8836
# Epoch 6/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2832 - accuracy: 0.8946 - val_loss: 0.3366 - val_accuracy: 0.8812
# Epoch 7/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2715 - accuracy: 0.8992 - val_loss: 0.3001 - val_accuracy: 0.8906
# Epoch 8/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2613 - accuracy: 0.9015 - val_loss: 0.3251 - val_accuracy: 0.8838
# Epoch 9/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2503 - accuracy: 0.9056 - val_loss: 0.3009 - val_accuracy: 0.8896
# Epoch 10/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2400 - accuracy: 0.9102 - val_loss: 0.2906 - val_accuracy: 0.8934
# Epoch 11/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2320 - accuracy: 0.9126 - val_loss: 0.2947 - val_accuracy: 0.8958
# Epoch 12/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2235 - accuracy: 0.9155 - val_loss: 0.3046 - val_accuracy: 0.8878
# Epoch 13/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2167 - accuracy: 0.9184 - val_loss: 0.3036 - val_accuracy: 0.8964
# Epoch 14/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2095 - accuracy: 0.9199 - val_loss: 0.3211 - val_accuracy: 0.8838
# Epoch 15/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2025 - accuracy: 0.9230 - val_loss: 0.2973 - val_accuracy: 0.8978
# Epoch 16/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1971 - accuracy: 0.9255 - val_loss: 0.3062 - val_accuracy: 0.8912
# Epoch 17/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1896 - accuracy: 0.9279 - val_loss: 0.3299 - val_accuracy: 0.8916
# Epoch 18/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1853 - accuracy: 0.9292 - val_loss: 0.3122 - val_accuracy: 0.8918
# Epoch 19/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1807 - accuracy: 0.9302 - val_loss: 0.3010 - val_accuracy: 0.8986
# Epoch 20/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1742 - accuracy: 0.9330 - val_loss: 0.3044 - val_accuracy: 0.8936
# Epoch 21/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1679 - accuracy: 0.9358 - val_loss: 0.3054 - val_accuracy: 0.8988
# Epoch 22/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1641 - accuracy: 0.9375 - val_loss: 0.3083 - val_accuracy: 0.8972
# Epoch 23/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1596 - accuracy: 0.9394 - val_loss: 0.3172 - val_accuracy: 0.8984
# Epoch 24/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1541 - accuracy: 0.9403 - val_loss: 0.3419 - val_accuracy: 0.8962
# Epoch 25/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1515 - accuracy: 0.9416 - val_loss: 0.3498 - val_accuracy: 0.8916
# Epoch 26/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1473 - accuracy: 0.9443 - val_loss: 0.3448 - val_accuracy: 0.8936
# Epoch 27/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1486 - accuracy: 0.9428 - val_loss: 0.3362 - val_accuracy: 0.8928
# Epoch 28/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1385 - accuracy: 0.9464 - val_loss: 0.3424 - val_accuracy: 0.8968
# Epoch 29/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1382 - accuracy: 0.9471 - val_loss: 0.3302 - val_accuracy: 0.8980
# Epoch 30/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1314 - accuracy: 0.9498 - val_loss: 0.3292 - val_accuracy: 0.9004

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)



model3 = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])
model3.summary()
Adam = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model3.compile(loss="sparse_categorical_crossentropy",
              optimizer=Adam,
              metrics=["accuracy"])
history3 = model3.fit(X_train, y_train, epochs=30,
                    validation_data=(X_valid, y_valid))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 300)               235500
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.4832 - accuracy: 0.8268 - val_loss: 0.3616 - val_accuracy: 0.8682
# Epoch 2/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.3624 - accuracy: 0.8664 - val_loss: 0.3770 - val_accuracy: 0.8656
# Epoch 3/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3278 - accuracy: 0.8789 - val_loss: 0.3185 - val_accuracy: 0.8822
# Epoch 4/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3023 - accuracy: 0.8876 - val_loss: 0.3142 - val_accuracy: 0.8856
# Epoch 5/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2862 - accuracy: 0.8930 - val_loss: 0.2946 - val_accuracy: 0.8934
# Epoch 6/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2700 - accuracy: 0.8999 - val_loss: 0.3327 - val_accuracy: 0.8814
# Epoch 7/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2591 - accuracy: 0.9031 - val_loss: 0.3052 - val_accuracy: 0.8902
# Epoch 8/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2471 - accuracy: 0.9068 - val_loss: 0.3011 - val_accuracy: 0.8952
# Epoch 9/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2373 - accuracy: 0.9101 - val_loss: 0.3048 - val_accuracy: 0.8966
# Epoch 10/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2251 - accuracy: 0.9146 - val_loss: 0.3001 - val_accuracy: 0.8966
# Epoch 11/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2190 - accuracy: 0.9165 - val_loss: 0.3177 - val_accuracy: 0.8882
# Epoch 12/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2094 - accuracy: 0.9204 - val_loss: 0.3286 - val_accuracy: 0.8988
# Epoch 13/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2023 - accuracy: 0.9238 - val_loss: 0.3053 - val_accuracy: 0.8980
# Epoch 14/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1946 - accuracy: 0.9258 - val_loss: 0.3183 - val_accuracy: 0.8966
# Epoch 15/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1883 - accuracy: 0.9287 - val_loss: 0.3187 - val_accuracy: 0.9006
# Epoch 16/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1827 - accuracy: 0.9300 - val_loss: 0.3440 - val_accuracy: 0.8956
# Epoch 17/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1760 - accuracy: 0.9337 - val_loss: 0.3146 - val_accuracy: 0.9042
# Epoch 18/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1706 - accuracy: 0.9351 - val_loss: 0.3503 - val_accuracy: 0.8982
# Epoch 19/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1691 - accuracy: 0.9367 - val_loss: 0.3574 - val_accuracy: 0.8988
# Epoch 20/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1584 - accuracy: 0.9389 - val_loss: 0.3416 - val_accuracy: 0.8952
# Epoch 21/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1556 - accuracy: 0.9400 - val_loss: 0.3985 - val_accuracy: 0.8894
# Epoch 22/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1533 - accuracy: 0.9402 - val_loss: 0.3688 - val_accuracy: 0.8988
# Epoch 23/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1471 - accuracy: 0.9440 - val_loss: 0.3756 - val_accuracy: 0.9016
# Epoch 24/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1438 - accuracy: 0.9449 - val_loss: 0.3869 - val_accuracy: 0.9024
# Epoch 25/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1402 - accuracy: 0.9463 - val_loss: 0.3860 - val_accuracy: 0.8980
# Epoch 26/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1372 - accuracy: 0.9476 - val_loss: 0.3668 - val_accuracy: 0.9010
# Epoch 27/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1312 - accuracy: 0.9496 - val_loss: 0.4348 - val_accuracy: 0.8964
# Epoch 28/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1343 - accuracy: 0.9492 - val_loss: 0.4135 - val_accuracy: 0.8958
# Epoch 29/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1282 - accuracy: 0.9511 - val_loss: 0.4030 - val_accuracy: 0.8988
# Epoch 30/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1225 - accuracy: 0.9517 - val_loss: 0.4122 - val_accuracy: 0.9044

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)



model4 = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])
model4.summary()
Adam2 = keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model4.compile(loss="sparse_categorical_crossentropy",
              optimizer=Adam2,
              metrics=["accuracy"])
history4 = model4.fit(X_train, y_train, epochs=30,
                    validation_data=(X_valid, y_valid))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 300)               235500
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.6118 - accuracy: 0.8014 - val_loss: 0.4339 - val_accuracy: 0.8528
# Epoch 2/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.4179 - accuracy: 0.8550 - val_loss: 0.3995 - val_accuracy: 0.8636
# Epoch 3/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3762 - accuracy: 0.8667 - val_loss: 0.3655 - val_accuracy: 0.8706
# Epoch 4/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.3496 - accuracy: 0.8767 - val_loss: 0.3499 - val_accuracy: 0.8750
# Epoch 5/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3314 - accuracy: 0.8816 - val_loss: 0.3272 - val_accuracy: 0.8820
# Epoch 6/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3158 - accuracy: 0.8869 - val_loss: 0.3293 - val_accuracy: 0.8830
# Epoch 7/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3042 - accuracy: 0.8906 - val_loss: 0.3151 - val_accuracy: 0.8858
# Epoch 8/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2916 - accuracy: 0.8956 - val_loss: 0.3112 - val_accuracy: 0.8894
# Epoch 9/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2808 - accuracy: 0.8988 - val_loss: 0.3083 - val_accuracy: 0.8898
# Epoch 10/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2708 - accuracy: 0.9021 - val_loss: 0.2982 - val_accuracy: 0.8922
# Epoch 11/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2630 - accuracy: 0.9049 - val_loss: 0.3015 - val_accuracy: 0.8926
# Epoch 12/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2550 - accuracy: 0.9072 - val_loss: 0.3034 - val_accuracy: 0.8920
# Epoch 13/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2474 - accuracy: 0.9107 - val_loss: 0.2915 - val_accuracy: 0.8940
# Epoch 14/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2400 - accuracy: 0.9139 - val_loss: 0.3070 - val_accuracy: 0.8880
# Epoch 15/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2352 - accuracy: 0.9142 - val_loss: 0.2927 - val_accuracy: 0.8890
# Epoch 16/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2280 - accuracy: 0.9180 - val_loss: 0.2970 - val_accuracy: 0.8896
# Epoch 17/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2210 - accuracy: 0.9206 - val_loss: 0.2927 - val_accuracy: 0.8928
# Epoch 18/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2151 - accuracy: 0.9224 - val_loss: 0.2865 - val_accuracy: 0.8982
# Epoch 19/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2099 - accuracy: 0.9252 - val_loss: 0.2925 - val_accuracy: 0.8962
# Epoch 20/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2043 - accuracy: 0.9273 - val_loss: 0.2880 - val_accuracy: 0.8958
# Epoch 21/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1974 - accuracy: 0.9291 - val_loss: 0.2926 - val_accuracy: 0.8958
# Epoch 22/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1939 - accuracy: 0.9305 - val_loss: 0.2915 - val_accuracy: 0.8986
# Epoch 23/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1882 - accuracy: 0.9314 - val_loss: 0.2941 - val_accuracy: 0.8936
# Epoch 24/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1831 - accuracy: 0.9333 - val_loss: 0.2899 - val_accuracy: 0.8932
# Epoch 25/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1778 - accuracy: 0.9360 - val_loss: 0.2911 - val_accuracy: 0.8986
# Epoch 26/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1731 - accuracy: 0.9380 - val_loss: 0.2922 - val_accuracy: 0.8938
# Epoch 27/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1692 - accuracy: 0.9402 - val_loss: 0.2981 - val_accuracy: 0.8986
# Epoch 28/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1650 - accuracy: 0.9409 - val_loss: 0.2912 - val_accuracy: 0.8974
# Epoch 29/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1610 - accuracy: 0.9419 - val_loss: 0.3000 - val_accuracy: 0.8960
# Epoch 30/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1550 - accuracy: 0.9441 - val_loss: 0.2924 - val_accuracy: 0.8978

# %%
import pandas as pd

pd.DataFrame(history2.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
import pandas as pd

pd.DataFrame(history3.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
import pandas as pd

pd.DataFrame(history4.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()
